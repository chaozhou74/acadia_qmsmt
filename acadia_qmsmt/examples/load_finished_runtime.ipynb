# %% [markdown]
# ## Example of loading back a finished runtime

# %%
from acadia_qmsmt.utils import load_runtime_from_data_dir
# this function will automatically try to find the runtime class that is defined in the saved `runtime.py` in the data folder,
# so we don't have to manually import it.
# read the doc of `acadia_qmsmt.utils.save_runtime_loader` for more details

data_path = r"/home/chao/Data/LINC_Cooldown_20250506/ChipA/RoSpec/250528/014616" # path to the data folder
rt = load_runtime_from_data_dir(data_path, use_saved_qmsmt=True) # now the state of this rt is the same as when the experiment was just finished
# Out:
# 500

# %%
rt.process_current_data()
rt.plot_data()
# Out:
# (<Figure size 640x480 with 2 Axes>,
#  array([<Axes: ylabel='Mag (a.u.)'>,
#         <Axes: xlabel='Frequency [Hz]', ylabel='Phase (deg)'>],
#        dtype=object))
